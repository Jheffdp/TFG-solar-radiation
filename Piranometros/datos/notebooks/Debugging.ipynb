# %%
import cv2

# %%
img1 = E:\TFG_Radiacion_entornos_urbanos\02.Cámara de cielo\Calibration_example\images

# %%
img1 = cv2.imread('../../../../02_camara_cielo/Calibration_example/images/C005_20200823_2020.jpg', 0)

# %%
img = cv2.imread('./C005_20200823_2020.jpg', 0)

# %%
img
# Out:
# array([[ 9, 16, 12, ...,  5, 13, 15],
#        [15, 16, 12, ...,  8, 13, 13],
#        [12, 12, 12, ..., 11, 13, 10],
#        ...,
#        [15, 10, 10, ..., 15, 14, 13],
#        [14,  8,  8, ..., 14, 14, 12],
#        [15,  5,  1, ..., 13, 12,  8]], dtype=uint8)

# %%
img1
# Out:
# array([[ 9, 16, 12, ...,  5, 13, 15],
#        [15, 16, 12, ...,  8, 13, 13],
#        [12, 12, 12, ..., 11, 13, 10],
#        ...,
#        [15, 10, 10, ..., 15, 14, 13],
#        [14,  8,  8, ..., 14, 14, 12],
#        [15,  5,  1, ..., 13, 12,  8]], dtype=uint8)
